# %% [markdown]
# # Assignment 3 (Week 3)
#
# >**Note**: Late submissions are ***`penalized`***.
#
# ## Name: Ifeoluwa Oduwaiye
#
# <br>
#
# ### Please show and display all your calculations and results.

# %%
# Standard imports
import numpy as np
import pandas as pd

# pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 1_000

# Black code formatter (Optional)
#%load_ext lab_black

# %% [markdown]
# ## Qs 1
#
# **a.** Given that
#
# ```python
# x = np.linspace(0, 10, 10001)
# ```
#
# using **ONLY** `NumPy`, write an equation that calculates `y`. `y` is calculated using the equation below:
#
# $$
# y = \exp^{(\frac{-x}{10})}*\sin{(x)}
# $$
#
# <br>
#
# **b.** Write a NumPy code that calculates:
#
# $$
# result = \frac{\sum{((x - \bar{x}) * (y - \bar{y}))}}{\sum{(x - \bar{x})^2}}
# $$
#
#
# `X` and `y` are given below:
#
# ```python
# rng = np.random.default_rng(seed=5)
# X = rng.random(size=(35, 2), dtype=np.float32)
# y = rng.random(size=(35, 1), dtype=np.float32)
# ```

# %%
x = np.linspace(0, 10, 10001)

# %%
# Write your solution here
# Qs 1a

y = np.exp((-x)/10) * np.sin(x)

# %%
rng = np.random.default_rng(seed=5)
X = rng.random(size=(35, 2), dtype=np.float32)
y = rng.random(size=(35, 1), dtype=np.float32)

# %%
# Write your solution here
# Qs 1b

result = (np.sum((X-np.abs(X))*(y-np.abs(y))))/np.sum((X-np.abs(X))**2)
# Out:
# <ipython-input-5-5ed5098ad706>:4: RuntimeWarning: invalid value encountered in float_scalars
#   result = (np.sum((X-np.abs(X))*(y-np.abs(y))))/np.sum((X-np.abs(X))**2)

# %%
result
# Out:
# nan

# %% [markdown]
# ## Qs 2
#
# Given the **`4-D`** array below:
#
# ```python
# rng = np.random.default_rng(seed=5)
# X = rng.random(size=(16, 3), dtype=np.float32).reshape(2, 4, 2, 3)
# ```
#
# Find:
#
# **a.** 0.1777215
#
# **b.** 0.51532555
#
# **c.**

# %%
rng = np.random.default_rng(seed=5)
X = rng.random(size=(16, 3), dtype=np.float32).reshape(2, 4, 2, 3)

# %%
X
# Out:
# array([[[[0.67079   , 0.80500287, 0.02265316],
#          [0.8079408 , 0.46885186, 0.51532555]],
#
#         [[0.630234  , 0.28580135, 0.97952366],
#          [0.0539307 , 0.2779237 , 0.38336885]],
#
#         [[0.57118434, 0.4084732 , 0.1310609 ],
#          [0.04527515, 0.00101531, 0.04875767]],
#
#         [[0.14881468, 0.9991761 , 0.19098222],
#          [0.6523691 , 0.75025886, 0.23451018]]],
#
#
#        [[[0.28223735, 0.43494755, 0.2632376 ],
#          [0.9741862 , 0.1777215 , 0.8976776 ]],
#
#         [[0.7976888 , 0.844231  , 0.11573023],
#          [0.39240462, 0.62803024, 0.49302298]],
#
#         [[0.66586643, 0.6766893 , 0.6629264 ],
#          [0.0608027 , 0.95909935, 0.5555961 ]],
#
#         [[0.90351176, 0.2714516 , 0.3615182 ],
#          [0.8796511 , 0.18690258, 0.06421441]]]], dtype=float32)

# %%
X.shape
# Out:
# (2, 4, 2, 3)

# %%
# Write your solution here
# Qs 2a

X[1][0][1][1]
# Out:
# 0.1777215

# %%
# Write your solution here
# Qs 2b

X[0][0][1][2]
# Out:
# 0.51532555

# %% [markdown]
# ## Qs 3
#
# Using Pandas, find the number of employees that:
#
# **a.** Write a query/code that determines the employees that are older than **30** years and their job role is either **manager** or **research director** or **manufacturing director** and have a **performance rating** greater than **3**.
#
# **b.** Create a new column that combines `technical degree`, `other` and `human resources` from **`education field`** into a new label called **others**. i.e the resulting column should have four (4) unique labels namely: **`life sciences`**, **`medical`**, **`marketing`** and **`others`**. Hint: Use `.apply()`
#
# **c.** Write a code that splits the data into **numerical** and **categorical** data. Display the **first 5 rows** of your results on separate cells using `.head()`.
#
# #### The data can be found [here](https://drive.google.com/file/d/1SSOdAGm0nCpPhKCqA1rgW00mwpseL7Dj/view?usp=share_link)

# %%
df = pd.read_csv("/content/HR_Employee_reduced.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#                  JobRole  EnvironmentSatisfaction  Gender  PerformanceRating  \
# 0        Sales Executive                        2  Female                  3
# 1     Research Scientist                        3    Male                  4
# 2  Laboratory Technician                        4    Male                  3
# 3     Research Scientist                        4  Female                  3
# 4  Laboratory Technician                        1    Male                  3
#
#    HourlyRate  JobInvolvement  JobLevel
# 0          94               3         2
# 1          61               2         2
# 2          92               2         1
# 3          56               3         1
# 4          40               3         1

# %%
df.JobRole.value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df.Age.dtype
# Out:
# dtype('int64')

# %%
# Write your solution here
# Qs 3a

filtered_values = np.where((df['PerformanceRating']>3) & (df['Age']>30) & (df['JobRole'].isin(['Manager', 'Research Director', 'Manufacturing Director'])))
df.loc[filtered_values]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 8      38        No  Travel_Frequently        216  Research & Development
# 60     32        No      Travel_Rarely        427  Research & Development
# 75     31        No      Travel_Rarely        746  Research & Development
# 105    59        No         Non-Travel       1420         Human Resources
# 135    36        No      Travel_Rarely        216  Research & Development
# 194    45        No         Non-Travel       1195  Research & Development
# 235    43        No      Travel_Rarely       1034                   Sales
# 325    31        No  Travel_Frequently        798  Research & Development
# 352    48        No      Travel_Rarely        530                   Sales
# 434    31        No      Travel_Rarely       1274  Research & Development
# 445    55        No      Travel_Rarely       1117                   Sales
# 451    42        No      Travel_Rarely        319  Research & Development
# 456    31        No      Travel_Rarely        688                   Sales
# 609    43        No      Travel_Rarely        589  Research & Development
# 611    35        No      Travel_Rarely        950  Research & Development
# 627    52        No  Travel_Frequently        890  Research & Development
# 635    35        No      Travel_Rarely        607  Research & Development
# 661    43        No      Travel_Rarely        177  Research & Development
# 714    50        No      Travel_Rarely       1126  Research & Development
# 746    41        No         Non-Travel        247  Research & Development
# 804    48        No         Non-Travel       1262  Research & Development
# 817    36        No         Non-Travel        217  Research & Development
# 861    46        No      Travel_Rarely       1402                   Sales
# 867    50        No  Travel_Frequently       1421  Research & Development
# 882    36        No      Travel_Rarely        363  Research & Development
# 918    51        No  Travel_Frequently        237                   Sales
# 936    45        No  Travel_Frequently        364  Research & Development
# 1009   58        No      Travel_Rarely       1055  Research & Development
# 1075   32        No      Travel_Rarely        495  Research & Development
# 1076   54        No  Travel_Frequently       1050  Research & Development
# 1096   40        No      Travel_Rarely        898         Human Resources
# 1116   55        No      Travel_Rarely        685                   Sales
# 1129   42        No      Travel_Rarely       1059  Research & Development
# 1166   48        No  Travel_Frequently        365  Research & Development
# 1175   39        No      Travel_Rarely        492  Research & Development
# 1096            1550                 Manager                        3    Male
# 1116            1578                 Manager                        3    Male
# 1129            1595                 Manager                        4    Male
# 1166            1644                 Manager                        3    Male
# 1175            1654  Manufacturing Director                        4    Male
# 1184            1665                 Manager                        2  Female
# 1185            1666       Research Director                        3    Male
# 1239            1736  Manufacturing Director                        4  Female
# 1268            1775  Manufacturing Director                        1  Female
# 1284            1800       Research Director                        3    Male
# 1301            1824                 Manager                        2    Male
# 1372            1936  Manufacturing Director                        1    Male
# 1394            1966  Manufacturing Director                        4    Male
# 1405            1979       Research Director                        3  Female
# 1432            2017       Research Director                        3  Female
# 1445            2034  Manufacturing Director                        1  Female
#
#       PerformanceRating  HourlyRate  JobInvolvement  JobLevel
# 8                     4          44               2         3
# 60                    4          33               3         2
# 75                    4          61               3         2
# 105                   4          32               2         5
# 135                   4          84               3         2
# 194                   4          65               2         4
# 235                   4          80               3         4
# 325                   4          48               2         3
# 352                   4          91               3         3
# 434                   4          33               3         3
# 445                   4          83               3         4
# 451                   4          56               3         3
# 456                   4          44               2         3
# 609                   4          94               3         4
# 611                   4          59               3         3
# 627                   4          81               2         4
# 635                   4          66               2         3
# 661                   4          55               3         2
# 714                   4          66               3         4
# 746                   4          55               1         5
# 804                   4          35               4         4
# 817                   4          78               3         2
# 861                   4          69               3         4
# 867                   4          30               3         4
# 882                   4          77               1         3
# 918                   4          83               3         5
# 936                   4          83               3         5
# 1009                  4          76               3         5
# 1075                  4          64               3         3
# 1076                  4          87               3         4
# 1096                  4          38               3         4
# 1116                  4          60               2         5
# 1129                  4          93               2         5
# 1166                  4          89               2         4
# 1175                  4          66               3         2
# 1184                  4          91               3         4
# 1185                  4          65               2         4
# 1239                  4          30               3         2
# 1268                  4          60               2         4
# 1284                  4          65               3         3
# 1301                  4          52               3         4
# 1372                  4          87               3         2
# 1394                  4          56               2         2
# 1405                  4          40               3         3
# 1432                  4          42               4         3
# 1445                  4          60               2         4

# %%
# Write your solution here
# Qs 3b

df['EducationField'] = np.where(df['EducationField']=='Life Sciences', 'Life Sciences', np.where(df['EducationField']=='Medical', "Medical", np.where(df['EducationField']=="Marketing", "Marketing", "Others")))

# %%
df.EducationField.value_counts()
# Out:
# Life Sciences    606
# Medical          464
# Others           241
# Marketing        159
# Name: EducationField, dtype: int64

# %%
# Write your solution here
# Qs 3c

numeric_df = df.select_dtypes(include=[np.number])
numeric_df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  PerformanceRating  HourlyRate  JobInvolvement  \
# 0                        2                  3          94               3
# 1                        3                  4          61               2
# 2                        4                  3          92               2
# 3                        4                  3          56               3
# 4                        1                  3          40               3
#
#    JobLevel
# 0         2
# 1         2
# 2         1
# 3         1
# 4         1

# %%
categorical_df = df.select_dtypes(exclude=[np.number])
categorical_df.head()
# Out:
#   Attrition     BusinessTravel              Department EducationField  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences
# 1        No  Travel_Frequently  Research & Development  Life Sciences
# 2       Yes      Travel_Rarely  Research & Development         Others
# 3        No  Travel_Frequently  Research & Development  Life Sciences
# 4        No      Travel_Rarely  Research & Development        Medical
#
#                  JobRole  Gender
# 0        Sales Executive  Female
# 1     Research Scientist    Male
# 2  Laboratory Technician    Male
# 3     Research Scientist  Female
# 4  Laboratory Technician    Male

# %% [markdown]
# ## Qs 4
#
# Given the data below:
#
# ```python
# salary = [74454, 54900, 76182, 56221, 81254, 75900, 67122, 62426, 61553,
#        77070, 67587, 50095, 75820, 68174, 79069]
# students = [
#     "Sadiq",
#     "Aminu",
#     "Udensi",
#     "Olayiwola",
#     "Ukpeh",
#     "Akinbade",
#     "Ezeofor",
#     "Oludele",
#     "Gbenga",
#     "Edgar",
#     "Worlu",
#     "Magbuwe",
#     "Atte",
#     "Orogun",
#     "Bamigbade"
# ]
#
# roles = [
#     "Data Engineer",
#     "Data Scientist",
#     "DevOps Engineer",
#     "Research Engineer",
#     "Analytical Engineer",
#     "Data Analyst",
#     "ML Engineer",
#     "DevOps Engineer",
#     "Analytical Engineer",
#     "Data Scientist",
#     "MLOps Engineer",
#     "Data Engineer",
#     "Data Scientist",
#     "ML Engineer",
#     "Research Engineer",
# ]
# ```
#
# **a.** Create a `DataFrame` using the lists above. The column names should be: `name` , `job_role` and `salary`.
#
# **b.** Create a new column **`title`** that has has 2 new labels `Engineer` and `Analyst/Scientist` if the person has `engineer` or `analyst/scientist` in their job role.
#
# **c.** What is the mean and median salary per `title`?

# %%
salary = [74454, 54900, 76182, 56221, 81254, 75900, 67122, 62426, 61553,
       77070, 67587, 50095, 75820, 68174, 79069]
students = [
    "Sadiq",
    "Aminu",
    "Udensi",
    "Olayiwola",
    "Ukpeh",
    "Akinbade",
    "Ezeofor",
    "Oludele",
    "Gbenga",
    "Edgar",
    "Worlu",
    "Magbuwe",
    "Atte",
    "Orogun",
    "Bamigbade"
]

roles = [
    "Data Engineer",
    "Data Scientist",
    "DevOps Engineer",
    "Research Engineer",
    "Analytical Engineer",
    "Data Analyst",
    "ML Engineer",
    "DevOps Engineer",
    "Analytical Engineer",
    "Data Scientist",
    "MLOps Engineer",
    "Data Engineer",
    "Data Scientist",
    "ML Engineer",
    "Research Engineer",
]

# %%
# Write your solution here
# Qs 4a

dict_ = {'name':students, 'job_role':roles, 'salary':salary}

df = pd.DataFrame(dict_)

# %%
df.head(10)
# Out:
#         name             job_role  salary
# 0      Sadiq        Data Engineer   74454
# 1      Aminu       Data Scientist   54900
# 2     Udensi      DevOps Engineer   76182
# 3  Olayiwola    Research Engineer   56221
# 4      Ukpeh  Analytical Engineer   81254
# 5   Akinbade         Data Analyst   75900
# 6    Ezeofor          ML Engineer   67122
# 7    Oludele      DevOps Engineer   62426
# 8     Gbenga  Analytical Engineer   61553
# 9      Edgar       Data Scientist   77070

# %%
# Write your solution here
# Qs 4b

df['title'] = np.where(df['job_role'].str.contains("Engineer"), 'engineer', 'analyst/scientist')

# %%
df.head()
# Out:
#         name             job_role  salary              title
# 0      Sadiq        Data Engineer   74454           engineer
# 1      Aminu       Data Scientist   54900  analyst/scientist
# 2     Udensi      DevOps Engineer   76182           engineer
# 3  Olayiwola    Research Engineer   56221           engineer
# 4      Ukpeh  Analytical Engineer   81254           engineer

# %%
# Write your solution here
# Qs 4c

df.groupby('title')['salary'].mean()
# Out:
# title
# analyst/scientist    70922.500000
# engineer             67648.818182
# Name: salary, dtype: float64

# %%
df.groupby('title')['salary'].median()
# Out:
# title
# analyst/scientist    75860.0
# engineer             67587.0
# Name: salary, dtype: float64
